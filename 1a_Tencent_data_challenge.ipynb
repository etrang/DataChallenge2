# %% [markdown]
# # Data Challenge
# By: Eddy Trang
#
# ***
# ***
#
# #### Tasks:
# 1. Search for Tencent’s official website from a search engine.
# 2. From the search engine results, find link to official website and use it to enter Tencent website to search for 2019 Tencent’s annual report
# 3. Download Tencent’s 2019 annual report, in pdf format, to the “Download” folder of your local computer.
# 4. Extract the information under the section “SUBSIDIARIES AND CONTROLLED STRUCTURED ENTITIES” but only the following columns are relevant:
#    - Name of the principal subsidiaries
#    - Particulars of issued/paid-in capital for each subsidiary
#    - Proportion of equity interest held by the Group (%) for each subsidiary
# 5. Perform fuzzy matching on each subsidiary name against each of the other subsidiaries’ names. Fuzzy matching is a technique that matches strings together that fits a particular pattern approximately. You will need to record:
#    - “Yes” if the fuzzy match is an “approximate match”, along with what the top matched name was to (i.e. the matched subsidiary name)
#    - Note that you will need to define “approximate match” and explain your reasoning. Your answer can be placed in the output xlsx file in a separate tab.
#    - “No” if the fuzzy match is not an approximate match
# 6. Output the results into the below five columns within a xlsx file:
#    - Name
#    - Capital
#    - Interest
#    - Match (Yes / No)
#    - Matched subsidiary name
#
# ***
# ***

# %% [markdown]
# # Outline
# #### I.    Format Working Space
# #### II.   Necessary Imports
# #### III.  Search for Tencent's 2019 Annual Report and Download
# #### IV.  Data Extraction and Cleaning
# #### V.   Fuzzy Matching and Export to Excel
#
# ***
# ***

# %% [markdown]
# ## I. Format Working Space

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## II. Necessary Imports

# %%
from selenium import webdriver
import time
import camelot
import numpy as np
import pandas as pd

# %% [markdown]
# ## III. Search for Tencent's 2019 Annual Report and Download

# %% [markdown]
# **1. Set up ChromeDriver**

# %%
chromedriver = "/Users/eddytrang/Downloads/chromedriver" # path to the chromedriver executable
chromeOptions = webdriver.ChromeOptions()
prefs = {"plugins.always_open_pdf_externally": True}
chromeOptions.add_experimental_option("prefs",prefs)

driver = webdriver.Chrome(chromedriver, options=chromeOptions)

# %% [markdown]
# **2. Set up search query**

# %%
query = "tencent official website"
google_search = f"https://www.google.com.sg/search?q="
google_query = google_search + query.replace(' ', '+')
google_query
# Out:
# 'https://www.google.com.sg/search?q=tencent+official+website'

# %% [markdown]
# **3. Search for report**

# %%
#1. Perform Google search on "tencent official website"
driver.get(google_query)
time.sleep(5)  

#2. Click first link available
result = driver.find_element_by_tag_name('h3') #first result under h3
result.click()
time.sleep(5)

#3. Click "Accept all analytics cookies"
result2 = driver.find_element_by_xpath('/html/body/div/div[4]/div[3]/div[3]/div[1]')
result2.click()
time.sleep(2)

#4. Click "Investors"
result3 = driver.find_element_by_xpath('/html/body/div/div[1]/div[1]/ul/li[5]/a')
result3.click()
time.sleep(2)

# Click "2020 Annual Financial Report" to download
result4 = driver.find_element_by_xpath('//*[@id="investors-con-2"]/div/div[2]/div[2]/div[2]/div[2]/div[1]/div[1]/a/div[1]/p')
result4.click()
time.sleep(2)

# %% [markdown]
# ## IV. Data Extraction and Cleaning

# %% [markdown]
# ### Table 1: Page 302

# %% [markdown]
# **1. Read in Table 1 and Convert to Dataframe**

# %%
table1=camelot.read_pdf(r'/Users/eddytrang/Downloads/960eae1f18dd716fd3a7d704e123d7a5.pdf', flavor='stream',pages='302')
df1=table1[0].df

# %%
df1
# Out:
#                                           0                          1  \
# 0                                      Name     nature of legal entity
# 1                          Tencent Computer    Established in the PRC,
# 2                                            limited liability company
# 3                        Tencent Technology    Established in the PRC,
# 4                                                 wholly foreign owned
# 5                                                           enterprise
# 6         Shenzhen Shiji Kaixuan Technology    Established in the PRC,
# 7                           Company Limited  limited liability company
# 8   Tencent Cyber (Tianjin) Company Limited    Established in the PRC,
# 9                                                 wholly foreign owned
# 10                                                          enterprise
# 11         Tencent Asset Management Limited         Established in the
# 12                                             British Virgin Islands,
# 13                                           limited liability company
# 14             Tencent Technology (Beijing)    Established in the PRC,
# 15                          Company Limited       wholly foreign owned
# 16                                                          enterprise
# 17             Nanjing Wang Dian Technology    Established in the PRC,
# 18                          Company Limited  limited liability company
# 19                Beijing BIZCOM Technology    Established in the PRC,
# 20                          Company Limited  limited liability company
# 21           Beijing Starsinhand Technology    Established in the PRC,
# 22                          Company Limited  limited liability company
#
#                    2                 3  \
# 0            capital  by the Group (%)
# 1      RMB65,000,000              100%
# 2                           (Note (a))
# 3       USD2,000,000              100%
# 4
# 5
# 6      RMB11,000,000              100%
# 7                           (Note (a))
# 8      USD90,000,000              100%
# 9
# 10
# 11            USD100              100%
# 12
# 13
# 14      USD1,000,000              100%
# 15
# 16
# 17     RMB10,290,000              100%
# 18                          (Note (a))
# 19  RMB1,216,500,000              100%
# 20                          (Note (a))
# 21     RMB10,000,000              100%
# 22                          (Note (a))
#
#                                                4
# 0    Principal activities and place of operation
# 1          Provision of value-added services and
# 2     Internet advertisement services in the PRC
# 3      Development of softwares and provision of
# 4     information technology services in the PRC
# 5
# 6   Provision of Internet advertisement services
# 7                                     in the PRC
# 8      Development of softwares and provision of
# 9     information technology services in the PRC
# 10
# 11                 Asset management in Hong Kong
# 12
# 13
# 14         Development and sale of softwares and
# 15  provision of information technology services
# 16                                    in the PRC
# 17  Provision of value-added services in the PRC
# 18
# 19  Provision of value-added services in the PRC
# 20
# 21  Provision of value-added services in the PRC
# 22

# %% [markdown]
# **2. Clean Table 1**

# %%
#1. Drop non-relevant columns: Placement of establishment and Principal Activities
df1 = df1.drop(df1.columns[[1, 4]], axis=1)

#2. Drop rows with no values and first row
df1[0].replace('', np.nan, inplace=True)
df1.dropna(subset=[0], inplace=True)
df1=df1.iloc[1:]

#3. Reset index and add in column names
df1 = df1.reset_index(drop=True)
df1.columns = ['Name','Particulars of issued/paid-in capital','Proportion of equity interest held by the Group(%)']

#4. Loop through df to move "Company Limited" where it belongs. When the table was read in, there were some cases where Camelot did not include "Company Limited" as part of the company name
for index in df1.index:
    if df1.loc[index,'Name'] == 'Company Limited':
        df1.loc[index-1,'Name_official'] = df1.loc[index-1,'Name'] + ' ' + df1.loc[index,'Name']
    else:
        df1.loc[index,'Name_official'] = df1.loc[index,'Name']
        
#5. Add column names and drop old "Name" column
df1.dropna(subset=['Name_official'], inplace=True)
df1.drop('Name', axis=1, inplace=True)
df1 = df1[['Name_official', 'Particulars of issued/paid-in capital','Proportion of equity interest held by the Group(%)']]

# %%
df1
# Out:
#                                         Name_official  \
# 0                                    Tencent Computer
# 1                                  Tencent Technology
# 2   Shenzhen Shiji Kaixuan Technology Company Limited
# 4             Tencent Cyber (Tianjin) Company Limited
# 5                    Tencent Asset Management Limited
# 6        Tencent Technology (Beijing) Company Limited
# 8        Nanjing Wang Dian Technology Company Limited
# 10          Beijing BIZCOM Technology Company Limited
# 12     Beijing Starsinhand Technology Company Limited
#
#    Particulars of issued/paid-in capital  \
# 0                          RMB65,000,000
# 1                           USD2,000,000
# 2                          RMB11,000,000
# 4                          USD90,000,000
# 5                                 USD100
# 6                           USD1,000,000
# 8                          RMB10,290,000
# 10                      RMB1,216,500,000
# 12                         RMB10,000,000
#
#    Proportion of equity interest held by the Group(%)
# 0                                                100%
# 1                                                100%
# 2                                                100%
# 4                                                100%
# 5                                                100%
# 6                                                100%
# 8                                                100%
# 10                                               100%
# 12                                               100%

# %% [markdown]
# ### Table 2: Page 303

# %% [markdown]
# **1. Read in Table 2 and Convert to Dataframe**

# %%
table2=camelot.read_pdf(r'/Users/eddytrang/Downloads/960eae1f18dd716fd3a7d704e123d7a5.pdf', flavor='stream',pages='303')
df2=table2[0].df
df2
# Out:
#                                     0                          1  \
# 0                                Name     nature of legal entity
# 1            Tencent Cyber (Shenzhen)    Established in the PRC,
# 2                     Company Limited       wholly foreign owned
# 3                                                     enterprise
# 4       Tencent Technology (Shanghai)    Established in the PRC,
# 5                     Company Limited       wholly foreign owned
# 6                                                     enterprise
# 7        Tencent Technology (Chengdu)    Established in the PRC,
# 8                     Company Limited       wholly foreign owned
# 9                                                     enterprise
# 10         Tencent Technology (Wuhan)    Established in the PRC,
# 11                    Company Limited       wholly foreign owned
# 12                                                    enterprise
# 13  Tencent Cloud Computing (Beijing)    Established in the PRC,
# 14                    Company Limited  limited liability company
# 15                  Morespark Limited  Established in Hong Kong,
# 16                                     limited liability company
# 17      Beijing Tencent Culture Media    Established in the PRC,
# 18                    Company Limited  limited liability company
# 19                   Riot Games, Inc.         Established in the
# 20                                                United States,
# 21                                     limited liability company
# 22           China Literature Limited         Established in the
# 23                                               Cayman Islands,
# 24                                     limited liability company
#
#                    2                 3  \
# 0            capital  by the Group (%)
# 1      USD30,000,000              100%
# 2
# 3
# 4       USD5,000,000              100%
# 5
# 6
# 7     USD220,000,000              100%
# 8
# 9
# 10     USD30,000,000              100%
# 11
# 12
# 13  RMB1,042,500,000              100%
# 14                          (Note (a))
# 15          HKD1,000              100%
# 16
# 17      RMB5,000,000              100%
# 18
# 19          USD1,306              100%
# 20
# 21
# 22        USD101,578           57.57%*
# 23
# 24
#
#                                               4
# 0   Principal activities and place of operation
# 1           Development of softwares in the PRC
# 2
# 3
# 4     Development of softwares and provision of
# 5    information technology services in the PRC
# 6
# 7     Development of softwares and provision of
# 8    information technology services in the PRC
# 9
# 10    Development of softwares and provision of
# 11   information technology services in the PRC
# 12
# 13  Provision of information system integration
# 14                          services in the PRC
# 15   Investment holding and provision of online
# 16          advertisement services in Hong Kong
# 17       Design and production of advertisement
# 18                                   in the PRC
# 19    Development and operation of online games
# 20                         in the United States
# 21
# 22      Provision of online literature services
# 23                                   in the PRC
# 24

# %% [markdown]
# **2. Clean Table 2**

# %%
#1. Drop non-relevant columns: Placement of establishment and Principal Activities
df2 = df2.drop(df2.columns[[1, 4]], axis=1)

#2. Drop rows with no values and first row
df2[0].replace('', np.nan, inplace=True)
df2.dropna(subset=[0], inplace=True)
df2=df2.iloc[1:]

#3. Reset index and add in column names
df2 = df2.reset_index(drop=True)
df2.columns = ['Name','Particulars of issued/paid-in capital','Proportion of equity interest held by the Group(%)']

#4. Loop through df to move "Company Limited" where it belongs. When the table was read in, there were some cases where Camelot did not include "Company Limited" as part of the company name
for index in df1.index:
    for index in df2.index:
        if df2.loc[index,'Name'] == 'Company Limited':
            df2.loc[index-1,'Name_official'] = df2.loc[index-1,'Name'] + ' ' + df2.loc[index,'Name']
        else:
            df2.loc[index,'Name_official'] = df2.loc[index,'Name']
        
#5. Add column names and drop old "Name" column
df2.dropna(subset=['Name_official'], inplace=True)
df2.drop('Name', axis=1, inplace=True)
df2 = df2[['Name_official', 'Particulars of issued/paid-in capital','Proportion of equity interest held by the Group(%)']]

# %%
df2
# Out:
#                                         Name_official  \
# 0            Tencent Cyber (Shenzhen) Company Limited
# 2       Tencent Technology (Shanghai) Company Limited
# 4        Tencent Technology (Chengdu) Company Limited
# 6          Tencent Technology (Wuhan) Company Limited
# 8   Tencent Cloud Computing (Beijing) Company Limited
# 10                                  Morespark Limited
# 11      Beijing Tencent Culture Media Company Limited
# 13                                   Riot Games, Inc.
# 14                           China Literature Limited
#
#    Particulars of issued/paid-in capital  \
# 0                          USD30,000,000
# 2                           USD5,000,000
# 4                         USD220,000,000
# 6                          USD30,000,000
# 8                       RMB1,042,500,000
# 10                              HKD1,000
# 11                          RMB5,000,000
# 13                              USD1,306
# 14                            USD101,578
#
#    Proportion of equity interest held by the Group(%)
# 0                                                100%
# 2                                                100%
# 4                                                100%
# 6                                                100%
# 8                                                100%
# 10                                               100%
# 11                                               100%
# 13                                               100%
# 14                                            57.57%*

# %% [markdown]
# ### Table 3: Page 304

# %% [markdown]
# **1. Read in Table 3 and Convert to Dataframe**

# %%
table3=camelot.read_pdf(r'/Users/eddytrang/Downloads/960eae1f18dd716fd3a7d704e123d7a5.pdf', flavor='stream',pages='304',table_areas=['0,600,1000,400'])
df3=table3[0].df
df3
# Out:
#                                 0                        1  \
# 0                             TME
# 1
# 2
# 3                    Supercell Oy
# 4
# 5  Shenzhen Tencent Culture Media
# 6                                          Company Limited
# 7                               *  on an outstanding basis
#
#                            2             3        4  \
# 0         Established in the    USD277,999  49.06%*
# 1            Cayman Islands,
# 2  limited liability company
# 3    Established in Finland,      EUR2,500   70.03%
# 4  limited liability company
# 5    Established in the PRC,  RMB5,000,000     100%
# 6  limited liability company
# 7
#
#                                            5
# 0    Provision of online music entertainment
# 1                        services in the PRC
# 2
# 3  Development and operation of mobile games
# 4                                 in Finland
# 5     Design and production of advertisement
# 6                                 in the PRC
# 7

# %% [markdown]
# **2. Clean Table 2**

# %%
#1. Move all strings in column 1 to column 0
df3[0] = df3[0] + df3[1]

#2. Drop non-relevant columns
df3 = df3.drop(df3.columns[[1, 2, 5]], axis=1)

#3. Drop rows with no values and first row
df3[0].replace('', np.nan, inplace=True)
df3.dropna(subset=[0], inplace=True)

#4. Reset index and add in column names
df3 = df3.reset_index(drop=True)
df3.columns = ['Name','Particulars of issued/paid-in capital','Proportion of equity interest held by the Group(%)']

#5. Loop through df to move "Company Limited" where it belongs. When the table was read in, there were some cases where Camelot did not include "Company Limited" as part of the company name
for index in df3.index:
    if df3.loc[index,'Name'] == 'Company Limited':
        df3.loc[index-1,'Name_official'] = df3.loc[index-1,'Name'] + ' ' + df3.loc[index,'Name']
    else:
        df3.loc[index,'Name_official'] = df3.loc[index,'Name']
        
#6. Add column names and drop old "Name" column
df3.dropna(subset=['Name_official'], inplace=True)
df3.drop('Name', axis=1, inplace=True)
df3 = df3[['Name_official', 'Particulars of issued/paid-in capital','Proportion of equity interest held by the Group(%)']]
df3=df3.iloc[:-1,:]

# %%
df3
# Out:
#                                     Name_official  \
# 0                                             TME
# 1                                    Supercell Oy
# 2  Shenzhen Tencent Culture Media Company Limited
#
#   Particulars of issued/paid-in capital  \
# 0                            USD277,999
# 1                              EUR2,500
# 2                          RMB5,000,000
#
#   Proportion of equity interest held by the Group(%)
# 0                                            49.06%*
# 1                                             70.03%
# 2                                               100%

# %% [markdown]
# ### Combine the 3 dataframes

# %%
frames = [df1, df2, df3]
main_df = pd.concat(frames)
main_df = main_df.reset_index(drop=True)
main_df.rename(columns={'Name_official': 'Name'}, inplace=True)

# %%
main_df
# Out:
#                                                  Name  \
# 0                                    Tencent Computer
# 1                                  Tencent Technology
# 2   Shenzhen Shiji Kaixuan Technology Company Limited
# 3             Tencent Cyber (Tianjin) Company Limited
# 4                    Tencent Asset Management Limited
# 5        Tencent Technology (Beijing) Company Limited
# 6        Nanjing Wang Dian Technology Company Limited
# 7           Beijing BIZCOM Technology Company Limited
# 8      Beijing Starsinhand Technology Company Limited
# 9            Tencent Cyber (Shenzhen) Company Limited
# 10      Tencent Technology (Shanghai) Company Limited
# 11       Tencent Technology (Chengdu) Company Limited
# 12         Tencent Technology (Wuhan) Company Limited
# 13  Tencent Cloud Computing (Beijing) Company Limited
# 14                                  Morespark Limited
# 15      Beijing Tencent Culture Media Company Limited
# 16                                   Riot Games, Inc.
# 17                           China Literature Limited
# 18                                                TME
# 19                                       Supercell Oy
# 20     Shenzhen Tencent Culture Media Company Limited
#
#    Particulars of issued/paid-in capital  \
# 0                          RMB65,000,000
# 1                           USD2,000,000
# 2                          RMB11,000,000
# 3                          USD90,000,000
# 4                                 USD100
# 5                           USD1,000,000
# 6                          RMB10,290,000
# 7                       RMB1,216,500,000
# 8                          RMB10,000,000
# 9                          USD30,000,000
# 10                          USD5,000,000
# 11                        USD220,000,000
# 12                         USD30,000,000
# 13                      RMB1,042,500,000
# 14                              HKD1,000
# 15                          RMB5,000,000
# 16                              USD1,306
# 17                            USD101,578
# 18                            USD277,999
# 19                              EUR2,500
# 20                          RMB5,000,000
#
#    Proportion of equity interest held by the Group(%)
# 0                                                100%
# 1                                                100%
# 2                                                100%
# 3                                                100%
# 4                                                100%
# 5                                                100%
# 6                                                100%
# 7                                                100%
# 8                                                100%
# 9                                                100%
# 10                                               100%
# 11                                               100%
# 12                                               100%
# 13                                               100%
# 14                                               100%
# 15                                               100%
# 16                                               100%
# 17                                            57.57%*
# 18                                            49.06%*
# 19                                             70.03%
# 20                                               100%

# %% [markdown]
# ## V. Fuzzy Matching and Export to Excel

# %% [markdown]
# **1. Necessary Imports**

# %%
import fuzzywuzzy
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
# Out:
# /Users/eddytrang/opt/anaconda3/lib/python3.8/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# **2. Add all company names to a list**

# %%
company_list = main_df['Name'].to_list()

# %% [markdown]
# **3. Loop throgh "Name" column in main_df and perform fuzzy matching on each name**

# %%
Match = []
Matched_subsidiary_name = []

for company_name in main_df['Name']:
    new_company_list = company_list.copy()
    new_company_list.remove(company_name)
    
    score = process.extractOne(company_name,new_company_list,scorer=fuzz.partial_ratio)
    
    if score[1] > 83:
        Match.append('Yes')
        Matched_subsidiary_name.append(score[0])
    else:
        Match.append('No')
        Matched_subsidiary_name.append('')
    
    new_company_list=[]
    
main_df['Match'] = Match
main_df['Matched subsidiary name'] = Matched_subsidiary_name

# %%
main_df
# Out:
#                                                  Name  \
# 0                                    Tencent Computer
# 1                                  Tencent Technology
# 2   Shenzhen Shiji Kaixuan Technology Company Limited
# 3             Tencent Cyber (Tianjin) Company Limited
# 4                    Tencent Asset Management Limited
# 5        Tencent Technology (Beijing) Company Limited
# 6        Nanjing Wang Dian Technology Company Limited
# 7           Beijing BIZCOM Technology Company Limited
# 8      Beijing Starsinhand Technology Company Limited
# 9            Tencent Cyber (Shenzhen) Company Limited
# 10      Tencent Technology (Shanghai) Company Limited
# 11       Tencent Technology (Chengdu) Company Limited
# 12         Tencent Technology (Wuhan) Company Limited
# 13  Tencent Cloud Computing (Beijing) Company Limited
# 14                                  Morespark Limited
# 15      Beijing Tencent Culture Media Company Limited
# 16                                   Riot Games, Inc.
# 17                           China Literature Limited
# 18                                                TME
# 19                                       Supercell Oy
# 20     Shenzhen Tencent Culture Media Company Limited
#
#    Particulars of issued/paid-in capital  \
# 0                          RMB65,000,000
# 1                           USD2,000,000
# 2                          RMB11,000,000
# 3                          USD90,000,000
# 4                                 USD100
# 5                           USD1,000,000
# 6                          RMB10,290,000
# 7                       RMB1,216,500,000
# 8                          RMB10,000,000
# 9                          USD30,000,000
# 10                          USD5,000,000
# 11                        USD220,000,000
# 12                         USD30,000,000
# 13                      RMB1,042,500,000
# 14                              HKD1,000
# 15                          RMB5,000,000
# 16                              USD1,306
# 17                            USD101,578
# 18                            USD277,999
# 19                              EUR2,500
# 20                          RMB5,000,000
#
#    Proportion of equity interest held by the Group(%) Match  \
# 0                                                100%    No
# 1                                                100%   Yes
# 2                                                100%    No
# 3                                                100%   Yes
# 4                                                100%    No
# 5                                                100%   Yes
# 6                                                100%    No
# 7                                                100%    No
# 8                                                100%    No
# 9                                                100%   Yes
# 10                                               100%   Yes
# 11                                               100%   Yes
# 12                                               100%   Yes
# 13                                               100%    No
# 14                                               100%    No
# 15                                               100%   Yes
# 16                                               100%    No
# 17                                            57.57%*    No
# 18                                            49.06%*    No
# 19                                             70.03%    No
# 20                                               100%   Yes
#
#                            Matched subsidiary name
# 0
# 1     Tencent Technology (Beijing) Company Limited
# 2
# 3         Tencent Cyber (Shenzhen) Company Limited
# 4
# 5                               Tencent Technology
# 6
# 7
# 8
# 9          Tencent Cyber (Tianjin) Company Limited
# 10                              Tencent Technology
# 11                              Tencent Technology
# 12                              Tencent Technology
# 13
# 14
# 15  Shenzhen Tencent Culture Media Company Limited
# 16
# 17
# 18
# 19
# 20   Beijing Tencent Culture Media Company Limited

# %% [markdown]
# **4. Export dataframe as xlsx file**

# %%
main_df.to_excel (r'/Users/eddytrang/Desktop/Tencent_sub0427.xlsx', index = False, header=True)
